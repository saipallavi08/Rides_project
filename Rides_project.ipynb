# %% [markdown]
# <a href="https://colab.research.google.com/github/saipallavi08/Rides_project/blob/main/Rides_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project on Rides Analysis

# %% [markdown]
# ##req module

# %%
#!pip install numpy
#!pip install pandas
#!pip install seaborn
#!pip install matplotlib
#!pip install plotly

# %%
import plotly.express as px
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv("/content/rides.csv")

# %%
#printing original data
data1
# Out:
#       Drivers Active Per Hour  Riders Active Per Hour  Rides Completed
# 0                          72                     295            202.0
# 1                          50                      78             43.0
# 2                          40                     250            181.0
# 3                          78                     140            124.0
# 4                          74                     195            108.0
# ...                       ...                     ...              ...
# 1094                       55                     170            144.0
# 1095                       99                     141            117.0
# 1096                       43                      82             64.0
# 1097                       35                     127             90.0
# 1098                       32                      81             60.0
#
# [1099 rows x 3 columns]

# %%
#above data havinng null values
#now removeing null values

# %%
df=data1.dropna()
data=data1.dropna()
newdata=data1.dropna()

# %%
df.head()
# Out:
#    Drivers Active Per Hour  Riders Active Per Hour  Rides Completed
# 0                       72                     295            202.0
# 1                       50                      78             43.0
# 2                       40                     250            181.0
# 3                       78                     140            124.0
# 4                       74                     195            108.0

# %%
plt.figure(figsize=(10, 8))
plt.style.use('fivethirtyeight')
plt.title("Distribution of  Rides")
sns.distplot(data['Drivers Active Per Hour'])
plt.show()
# Out:
# <ipython-input-12-a5178d2b71d7>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Drivers Active Per Hour'])

# %%
plt.figure(figsize=(10, 8))
plt.style.use('fivethirtyeight')
plt.title("Distribution of Riders ")
sns.distplot(data['Riders Active Per Hour'])
plt.show()
# Out:
# <ipython-input-13-6c1902b8388d>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Riders Active Per Hour'])

# %%
plt.figure(figsize=(10, 8))
plt.style.use('fivethirtyeight')
plt.title("Distribution of Rides Completed ")
sns.distplot(data['Rides Completed'])
plt.show()
# Out:
# <ipython-input-14-c6c91b8616b2>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Rides Completed'])

# %%
a = data["Drivers Active Per Hour"].sum()
b = data["Riders Active Per Hour"].sum()
c = data["Rides Completed"].sum()
labels = ['Drivers per','Rider per hour','Rides completed']
values = [a,b,c]

fig = px.pie(data, values=values, names=labels,
             title='rider per hour driver per hour rides completed', hole=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
v=px.histogram(newdata,x='Drivers Active Per Hour',title="Drivers Active Per Hour")
v.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
v=px.histogram(newdata,x='Riders Active Per Hour',title="Riders Active Per Hour")
v.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
v=px.histogram(newdata,x='Rides Completed',title="Rides completed")
v.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.boxplot(x=df["Drivers Active Per Hour"])
# Out:
# <Axes: xlabel='Drivers Active Per Hour'>

# %%
sns.boxplot(x=df["Riders Active Per Hour"])
# Out:
# <Axes: xlabel='Riders Active Per Hour'>

# %%
sns.boxplot(x=df["Rides Completed"])
# Out:
# <Axes: xlabel='Rides Completed'>

# %%
sns.violinplot(x=df["Drivers Active Per Hour"])
# Out:
# <Axes: xlabel='Drivers Active Per Hour'>

# %%
#scatter plot
plt.scatter('Drivers Active Per Hour', 'Riders Active Per Hour', c ="blue")
# To show the plot
plt.show()

# %%
violin_plot= px.violin(data, x='Riders Active Per Hour', y='Drivers Active Per Hour',
                        title='Distribution of Supply Ratio across Different Levels of Riders Active Per Hour')
violin_plot.update_xaxes(title='Riders Active Per Hour')
violin_plot.update_yaxes(title='Supply Ratio')
violin_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
scatter_plot = px.scatter(data, x='Riders Active Per Hour', y='Rides Completed', title='Relationship between Riders Active Per Hour and Rides Completed')
scatter_plot.update_xaxes(title='Riders Active Per Hour')
scatter_plot.update_yaxes(title='Rides Completed')
scatter_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figure= px.scatter(data_frame = data, x='Drivers Active Per Hour',y='Riders Active Per Hour', trendline="ols",
                    title = "Relationship Drivers per Hour and Rider active per hour")
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
